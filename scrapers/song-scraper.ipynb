# %%
# !pip install lyricsgenius
import lyricsgenius
genius = lyricsgenius.Genius("XIDuPWsJHnmlvJQgXJf4VSSmh4iDmVbCLMswJJ2auiKc13RbXBuFowzf1WTI4ZRY")

# %%
pop_artists = ["Emir Can İğrek", "Tarkan", "Mabel Matiz", "Yalın", "Kenan Doğulu", "Buray", "Gökhan Türkmen", "Oğuzhan Koç", "Bilal Sonses", "Mustafa Sandal", 
                "Sezen Aksu", "Sıla", "Zeynep Bastık", "Sertab Erener", "Hande Yener", "Gülşen", "Göksel", "Yıldız Tilbe", "Demet Akalın", "Nil Karaibrahimgil",
                "Hadise", "Ece Seçkin", "Ayşe Hatun Önal", "Bengü", "Ferhat Göçer", "Gökhan Türkmen", "Gülben Ergen", "İrem Derici", "Murat Boz", "Işın Karaca"]

rap_artists = ["Anıl Piyancı", "Ben Fero", "Ceg", "Ceza", "Contra", "Eypio", "Ezhel", "Gazapizm", "Hidra", "Joker",
               "Khontkar", "Killa Hakan", "Massaka", "Önder Doğan", "Norm Ender", "Patron", "Sagopa Kajmer", "Şanışer", "Şehinşah", "Uzi"]

rock_artists = ["Mor ve Ötesi", "Şebnem Ferah", "Duman", "Teoman", "maNga", "Hayko Cepkin", "Özlem Tekin", "Pentegram", "Athena", "Aylin Aslım",
                "Kurban", "Ogün Sanlısoy", "Almora", "Demir Demirkan", "Sakin", "Yavuz Çetin", "110", "Grizu", "Malt", "Mavi Sakal"]

def scrape_lyrics(artist_name):
  whole_text = ""

  artist = genius.search_artist(artist_name, sort="title")

  for song in artist.songs:
  
    lyrics = song.lyrics
    whole_text += lyrics

  with open(str(artist_name) + '_lyrics_data_set.txt', 'w') as f:
    f.write(whole_text)

# %%
#for pop_artist in pop_artists:
  #scrape_lyrics(pop_artist)
  #print(pop_artist + " şarkıcının şarkıları kaydedildi.")


for rap_artist in rap_artists[16:]:
  scrape_lyrics(rap_artist)
  print(rap_artist + " şarkıcının şarkıları kaydedildi.")


for rock_artist in rock_artists:
  scrape_lyrics(rock_artist)
  print(rock_artist + " şarkıcının şarkıları kaydedildi.")
